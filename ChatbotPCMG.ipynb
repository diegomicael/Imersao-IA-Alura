# %% [markdown]
# <a href="https://colab.research.google.com/github/diegomicael/Imersao-IA-Alura/blob/main/ChatbotPCMG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
# Import the Python SDK
import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
   print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
generation_config = {
    "candidate_count": 1,
    "temperature" : 0.5,
    "top_p" : 0.5,
    "top_k" : 0.5,

}

# %%
safety_settings = {
    "Harassment": "BLOCK_NONE",
    "Hate": "BLOCK_NONE",
    "Sexual": "BLOCK_NONE",
    "Dangerous": "BLOCK_NONE",
    }

# %%
model = genai.GenerativeModel(model_name="gemini-1.0-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

# %%
import time

# %%
timer_start = time.time()  # Iniciar contagem ao iniciar o chatbot

# %%
from os import openpty

def chatbot():
  print("""Olá!

Este é o "CONECTA PCMG", canal de atendimento digital da 9ª Delegacia de Polícia
Civil de Abaeté-MG. Trata-se de um canal dedicado para envio de intimações,
captação de arquivos, mídias e dados relacionadas a procedimentos.

Digite o número correspondente ao setor ou informação desejada:
""")

  while True:
    menu = """
    Menu:
    1. Identidade
    2. Registro de Ocorrência
    3. Cópia de Ocorrência
    4. Denúncias
    5. Violência Doméstica / Medidas Protetivas
    6. Intimações
    7. Trânsito
    8. Atestado de Antecedentes
    9. Telefones úteis
    0. Envio de Arquivos

    Digitar - Para enviar uma mensagem
    Menu - Para voltar ao Menu Principal
    Sair - Encerrar atendimento
    """
    print(menu)

    opcao = input("Escolha uma opção: ")

    if opcao == '1':
      print("""
Como solicitar?

Para solicitar a emissão da carteira de identidade, é necessário realizar o
agendamento diretamente na Delegacia  de Polícia Civil de Abaeté, de Segunda à
Sexta, das 08hs30min às 10hs30min e de 14hs às 15hs30min.

Quais documentos levar?

•Se solteiro, certidão de nascimento.
•Se casado, certidão de casamento (obrigatoriamente caso o solicitante tenha
alterado o nome em razão do casamento) ou certidão de nascimento com a averbação
do casamento (se não houve alteração do nome em virtude do casamento).
•Se divorciado, certidão de casamento com averbação do divórcio ou certidão de
nascimento com averbação do divórcio.

Documentos opcionais que podem ser incluídos no RG, mediante comprovação:

•CPF
•CNH
•Titulo de Eleitoral
•Carteira de Trabalho
•Cartão do SUS
•Certificado de Reservista
•Carteira Profissional
•Tipo Sanguíneo

Importante:

•A certidão apresentada deverá ser original.
•A certidão deverá estar legível, sem rasgos, emendas ou rasuras que comprometam
a originalidade do documento.
•O menor de 16 anos deverá estar acompanhado pelo pai ou pela mãe, que deverá
apresentar documento oficial com foto que o (a) identifique.

Atenção:


A PRIMEIRA VIA DA NOVA CARTEIRA É GRATUITA.


•Não é mais necessário levar fotos 3x4. A fotografia será tirada no momento do
atendimento - com exceção de crianças que não possam posar sem amparo de
terceiros. Não é permitido tirar a fotografia usando qualquer espécie de
cobertura de cabeça (lenço, chapéu, boné) nem com óculos de sol. Serão aceitas
coberturas que compõem hábitos religiosos que façam parte do uso cotidiano do
portador ou em razão de motivos de saúde.


Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.
No site oficial, a delegacia online oferece links para os serviços e também para
outros recursos, como Polícia Civil e Detran MG.

A Delegacia Virtual MG  também fornece para download guias com informações sobre
o enfrentamento da violência doméstica e familiar contra a mulher.

O objetivo da criação da Delegacia Virtual é a diminuição no tempo de espera em
unidades policiais, além de combater a subnotificação de registros.
https://delegaciavirtual.sids.mg.gov.br/

Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.
      """)

    elif opcao == '2':
      print("""
DELEGACIA VIRTUAL DO ESTADO DE MINAS GERAIS

O serviço da Delegacia Virtual MG é mais uma maneira do cidadão fazer um
registro de ocorrência, com o diferencial de fazer o procedimento por meio da
internet.
No site oficial, a delegacia online oferece links para os serviços e também para
outros recursos, como Polícia Civil e Detran MG.

A Delegacia Virtual MG  também fornece para download guias com informações sobre
o enfrentamento da violência doméstica e familiar contra a mulher.
O objetivo da criação da Delegacia Virtual é a diminuição no tempo de espera em
unidades policiais, além de combater a subnotificação de registros.
https://delegaciavirtual.sids.mg.gov.br/

Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.
      """)
    elif opcao == '3':
      print("""
CÓPIA DE OCORRÊNCIA

Fornecimento de copia de ocorrência em arquivo digital, do Boletim de Ocorrência
Policial (BO) poderá ser solicitado através do site
https://cidadao.mg.gov.br/#/login?codRecurso=DELEGACIAVIRTUAL015

QUEM PODE UTILIZAR O SERVIÇO?

Qualquer cidadão que tenha registrado um Boletim de Ocorrência Policial (BO) ou
ainda que não tenha solicitado o registro, conste como um dos envolvidos na
ocorrência.

RESTRIÇÕES

Estão disponíveis para impressão os registros das seguintes naturezas:

•	Acidente de trânsito com vítima
•	Acidente de trânsito sem vítima
•	Ameaça
•	Aplicação das medidas administrativas Código de Trânsito Brasileiro (CTB)
•	Atrito verbal
•	Comunicação de pessoa extraviada ou desaparecida
•	Dano
•	Descumprimento de medida protetiva de urgência
•	Estelionato
•	Extravio de documentos
•	Extravio de objetos pessoais
•	Furto
•	Lesão corporal
•	Outras ações de defesa social
•	Outras infrações contra a pessoa
•	Outras infrações contra o patrimônio
•	Outras infrações demais leis especiais
•	Pessoa localizada
•	Roubo
•	Veículo localizado/recuperado
•	Vias de fato/agressão
•	Explosão e Incêndio
•	Prevenção e Vistoria
•	Atividades de proteção e Defesa Civil
•	Busca e salvamento
•	Atendimento Pré-hospitalar (APH)
•	Demonstrações, palestras e treinamentos
•	Comunicações, denúncias, reclamações e solicitações diversas
•	Coordenação e controle operacional e administrativo
•	Operações de Defesa Social

Caso tenha dificuldades em emitir o Boletim de Ocorrência Policial (BO) através
do site, poderá encaminhar o número do registro que encaminharemos o arquivo
assim que possível.

Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.
      """)
    elif opcao == '4':
      print("""
      DENÚNCIAS

Para denunciar, basta ligar, gratuitamente, para o número 181.O Disque Denúncia
funciona com uma central de atendimento unificada, formada por profissionais
treinados e capacitados que trabalham em regime de 24 horas para atender à
população.Cada denúncia registrada é encaminhada para uma equipe de analistas
composta por um integrante da Polícia Civil, da Polícia Militar e do Corpo de
Bombeiros.

Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.""")

    elif opcao == '5':
      print("""
      VIOLÊNCIA DOMÉSTICA / MEDIDAS PROTETIVAS

O registro de ocorrência relacionado com violência contra a mulher pode ser
feito:

* Delegacia Especializada em Atendimento à Mulher
* Em qualquer Delegacia de Polícia Civil de Minas Gerais
* Pela Delegacia Virtual https://delegaciavirtual.sids.mg.gov.br
Obs.: É possível registrar ocorrências de lesão corporal, vias de fato, ameaça e
 descumprimento de medida protetiva.
* Em qualquer unidade da Polícia Militar de Minas Gerais (PMMG).

Na delegacia, a mulher em situação de violência poderá:

•	 Solicitar medidas protetivas de urgência.
•	 Solicitar acompanhamento até o endereço informado para que ela possa retirar
seus pertences em segurança (roupas, documentos e medicamentos).
•	 Receber a guia de exame de corpo de delito.
•	 Solicitar encaminhamento para casas abrigo.
•	 Realizar a representação criminal para devida responsabilização do agressor.
•	 Ser encaminhada para serviços de atendimento psicossocial.
•	 Ser incluída em programa de prevenção da Policia Militar.
•	 Receber encaminhamento para orientação jurídica na Defensoria Pública.

Representação Criminal:

•Em alguns crimes, a investigação depende da representação da vítima.
•Medidas protetivas podem ser solicitadas sem representação, mas não há
investigação ou punição do agressor.
•Em outros casos, a investigação ocorre independente da vontade da vítima, como
em estupro, lesão corporal e tentativa de feminicídio.

Medidas Protetivas:

•Direitos previstos na Lei Maria da Penha para proteger mulheres em situação de
violência.
•Podem ser solicitadas em casos de violência física, psicológica, sexual,
patrimonial ou moral.
•Disponíveis para todas as mulheres, independente de orientação sexual, raça,
etnia, etc.

Solicitação de Medidas Protetivas:

•Pode ser feita na Delegacia de Polícia, Ministério Público ou Defensoria
Pública, sem advogado.
•Um juiz analisará o pedido e decidirá sobre as medidas.
•As medidas podem incluir: afastamento do agressor, proibição de contato, uso de
tornozeleira eletrônica, etc.
•As medidas são independentes do processo criminal e podem ser deferidas mesmo
que não haja crime.


Para mais informações baixe a cartilha da PCMG sobre Medida Protetiva através do
link https://www.policiacivil.mg.gov.br/site-pc/media/get/documento/3845194 ou
procure diretamente a Delegacia de Polícia Civil mais próxima.

Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.
      """)

    elif opcao == '6':
      print("""
      INTIMAÇÕES

Para maiores informações, comparecer à Delegacia de Policia Civil de Abaeté, Rua
Inácio de Oliveira Campos, nº 335, Bairro Amazonas, de posse do número do
procedimento, das 8hs às 12hs e das 14hs às 18hs. Nenhuma informação com
relação ao procedimento será repassada pelo telefone.
      """)

    elif opcao == '7':
      print("""
      TRÂNSITO

Serviços e informações oficiais sobre Veículos, Habilitação e Infrações, acesse
o site do Departamento de Trânsito de Minas Gerais - Detran-MG.
https://www.transito.mg.gov.br/ ou pessoalmente na unidade policial.

Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.
      """)

    elif opcao == '8':
      print("""
      ATESTADO DE ANTECEDENTES

O atestado de antecedentes é um documento gratuito emitido pela Polícia Civil,
por meio do Instituto de Identificação, que apresenta a existência ou não de
antecedentes criminais do cidadão requisitante no exato momento da solicitação.

Para os portadores de Carteira de Identidade do Estado de Minas Gerais, o
serviço está disponível on line. O Atestado de Antecedentes para portadores de
Carteira de Identidade de outros Estados deve ser requerido pessoalmente em uma
Unidade Integrada de Atendimento (UAI). No interior do Estado de Minas, onde não
houver atendimento nos Postos de Identificação, o interessado pode procurar uma
Delegacia de Polícia Civil mais próxima.

Menores de 18 anos não têm obrigação legal de apresentar Atestado de
Antecedentes. Diante disso, o sistema não emite o documento. Cabe salientar que
o não fornecimento do Atestado de Antecedentes não implica, necessariamente, a
existência de pendências jurídico-criminais.

https://wwws.pc.mg.gov.br/atestado

Esta é uma mensagem automática, dúvidas ligue (37) 3541-1489.
      """)

    elif opcao == '9':
      print("""
      TELEFONES ÚTEIS

Policia Civil de Abaeté (37)3541-1489
Polícia Militar (37)3541-1344
Disque Denúncia 181
Presídio (37)3541-1535
UPA (37)3541-5377
Promotoria (37)3541-1013
Fórum (37)3541-1797
Prefeitura (37)3541-5151
Conselho Tutelar (37)3541-5044
Clínica São José (37)3541-2272""")

    elif opcao == '0':
      print("""
      ENVIO DE ARQUIVOS

Ao encaminhar arquivos, fotos, áudios, prints, comprovantes e demais informações
 para instrução de procedimentos, favor constar os seguintes dados:

Nome completo e RG;
Numero da ocorrência ou do procedimento (caso saiba informar);
Nome do servidor responsável pelo atendimento.

Basta enviar os arquivos que estes serão incluídos nos respetivos procedimentos.
""")
      input("Digite sua mensagem: ")

    elif opcao.lower() == 'menu':
      continue  # Volta ao início do loop e mostra o menu
    elif opcao.lower() == 'digitar':
      input("Digite sua mensagem: ")
    elif opcao.lower()== 'sair':
      print("""
      Seu atendimento foi encerrado.
      A 9ª Delegacia de Polícia Civil de Abaeté agradece o seu contato.
      Caso ainda precise de nosso atendimento, digite: Menu""")

      input("Digite sua mensagem: ")

    elif opcao.lower() == 'Fim':
      break  # Sai do loop e encerra o atendimento


    else:
      print("Opção inválida. Por favor, escolha uma opção do menu.")

  print("""
Seu atendimento foi encerrado.
A 9ª Delegacia de Polícia Civil de Abaeté agradece o seu contato.""")



chatbot()
